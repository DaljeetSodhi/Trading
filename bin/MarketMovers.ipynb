# %%
import os, sys
if(not os.path.isfile('/usr/lib/x86_64-linux-gnu/libta_lib.a')): #talib needs these lib files  
    # !ln -s /content/drive/MyDrive/Trading/PyLibColab/libta_* /usr/lib/x86_64-linux-gnu
ColabLibPath='/content/drive/MyDrive/Trading/PyLibColab/';sys.path.insert(0, ColabLibPath)
os.chdir('/content/drive/MyDrive/Trading/bin')
import TradeUtils as tu
DaysData=tu.ProcessDaysData(True)
from google.colab import data_table
data_table.enable_dataframe_formatter()
data_table.DataTable(DaysData, include_index=False, num_rows_per_page=6)
# Out:
# 08 08:54:06 ===== Day Processing Fetching MCap/YHigh/YLow [* = 40 ] *****
# 08 08:54:21 Fetching Daily Candles [ 2022-04-09  to  2022-07-08 )
# [*********************100%***********************]  197 of 197 completed
# Data retreived range :  2022-04-11 00:00:00 2022-07-07 00:00:00
# 08 08:54:41 ===== Analysis
# Day High Circuit Only : ['NBCC.NS']
# Stock  Lot  LSize  MCap Ban HDiv  RSI  YLH%  LRm5  SD5%  LRm10  SD10%   Close  Close2%  Close%  High%  Low%
# ^NSEI <NA>    NaN  <NA>  No   No   56    28 87.21  1.17  28.75   0.97 16132.9      1.1     0.9    1.0   0.4
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Stock</th>
#       <th>Lot</th>
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive') 
#import os, sys
#ColabLibPath='/content/drive/MyDrive/Trading/PyLibColab'
#sys.path.insert(0, ColabLibPath)
#!pip uninstall warnings 
!#pip install --target=$ColabLibPath  warnings 
#import InterfaceUtils as iu
#iu.StockMenu(
#import warnings
#print(os.path.abspath(pandas_datareader.__file__))
#FnO=ou.GetFnOList(); DaysData=tu.AddDaysInfo(FnO); tu.DisplayData(DaysData, 'Day', 'Short', 6)
