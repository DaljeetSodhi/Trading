# %%
import OtherUtils as ou
import StockUtils as su
import GraphUtils as gu
import GlobalVars as gv

import ipywidgets as ipw
UI, Components= ou.CreatUI()
UI

# %%
Stocks=ou.GetStockList(Components[0].value, Components[1].value)
PatResult, Stock=su.FindStocks(Stocks)

# %%
gu.DrawGraphForStock(Components[0].value)
# Out:
# ()

# %%
import NSENDJComp
NSENDJComp.CompareNSEFalls(['Close'])
# Out:
# 11:30:32 Getting Data : 2020-01-01 00:00:00 2020-05-29 :
# ^NSEI
# [*********************100%***********************]  1 of 1 completed
# 11:30:32 Getting Data : 2007-01-01 00:00:00 2009-12-31 00:00:00 :
# ^NSEI
# [*********************100%***********************]  1 of 1 completed
# ()
